# %%
import pandas as pd
import os

# %%
files = os.listdir('/home/davialefe/docking/cov/ligands/pdb')
files
# Out:
# ['CN093.pdb',
#  'CN099.pdb',
#  'CN100.pdb',
#  'CN124.pdb',
#  'CN125.pdb',
#  'CN126.pdb',
#  'CN275.pdb',
#  'CN277.pdb',
#  'CN278.pdb',
#  'CN281.pdb',
#  'CN282.pdb',
#  'CN283.pdb',
#  'CN284.pdb',
#  'CN285.pdb',
#  'CN286.pdb',
#  'CN288.pdb',
#  'CN289.pdb',
#  'CN290.pdb',
#  'CN291.pdb',
#  'CN292.pdb',
#  'CN333.pdb',
#  'CN334.pdb',
#  'CN335.pdb',
#  'CN336.pdb',
#  'CN337.pdb',
#  'CN338.pdb',
#  'CN339.pdb',
#  'CN340.pdb',
#  'CN341.pdb',
#  'CN342.pdb',
#  'CN343.pdb',
#  'CN344.pdb',
#  'CN345.pdb',
#  'CN346.pdb',
#  'CN362.pdb',
#  'CN393.pdb',
#  'CN394.pdb',
#  'CN395.pdb']

# %%
files = pd.DataFrame(files)
files
# Out:
#             0
# 0   CN093.pdb
# 1   CN099.pdb
# 2   CN100.pdb
# 3   CN124.pdb
# 4   CN125.pdb
# 5   CN126.pdb
# 6   CN275.pdb
# 7   CN277.pdb
# 8   CN278.pdb
# 9   CN281.pdb
# 10  CN282.pdb
# 11  CN283.pdb
# 12  CN284.pdb
# 13  CN285.pdb
# 14  CN286.pdb
# 15  CN288.pdb
# 16  CN289.pdb
# 17  CN290.pdb
# 18  CN291.pdb
# 19  CN292.pdb
# 20  CN333.pdb
# 21  CN334.pdb
# 22  CN335.pdb
# 23  CN336.pdb
# 24  CN337.pdb
# 25  CN338.pdb
# 26  CN339.pdb
# 27  CN340.pdb
# 28  CN341.pdb
# 29  CN342.pdb
# 30  CN343.pdb
# 31  CN344.pdb
# 32  CN345.pdb
# 33  CN346.pdb
# 34  CN362.pdb
# 35  CN393.pdb
# 36  CN394.pdb
# 37  CN395.pdb

# %%
files.to_csv('ligands.csv', index=False, header=False)
